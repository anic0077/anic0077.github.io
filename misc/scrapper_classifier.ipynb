# %%
#packages
#import nbimporter
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import io
from PIL import Image
import hashlib

import selenium
from selenium import webdriver
import os
from image_scrapper_for_functions_2 import *
import signal
dir(signal)



#from test_import import test_func
#import image_scrapper_for_functions
#help(image_scrapper_for_functions)
#dir(image_scrapper_for_functions)
# Out:
# ['CTRL_BREAK_EVENT',
#  'CTRL_C_EVENT',
#  'Handlers',
#  'NSIG',
#  'SIGABRT',
#  'SIGBREAK',
#  'SIGFPE',
#  'SIGILL',
#  'SIGINT',
#  'SIGSEGV',
#  'SIGTERM',
#  'SIG_DFL',
#  'SIG_IGN',
#  'Signals',
#  '_IntEnum',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_enum_to_int',
#  '_int_to_enum',
#  '_signal',
#  'default_int_handler',
#  'getsignal',
#  'raise_signal',
#  'set_wakeup_fd',
#  'signal',
#  'strsignal',
#  'valid_signals']

# %%
#player
DRIVER_PATH = 'C:/Users/alexa/Documents/GitHub/anic0077.github.io/misc/chromedriver'
wd = webdriver.Chrome(executable_path=DRIVER_PATH)
wd.quit()

# %%
search_term = 'lavender'

search_and_download(
    search_term = search_term,
    driver_path = DRIVER_PATH,
    number_images = 500
)
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 159 image links, looking for more ...
# Found: 312 search results. Extracting links from 100:312
# Found: 501 image links, done!
# SUCCESS - saved https://cdn.shopify.com/s/files/1/1153/9196/products/LavenderA17_2048x.jpg?v=1508981571 - as ./images\lavender\e4901e5265.jpg
# SUCCESS - saved https://www.edenatbyron.com.au/wp-content/uploads/2017/06/The-age-old-lure-of-lavender-Photo-2.jpg - as ./images\lavender\1ed663244d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7TWifxju94nIV17ptTKDqKZupriHH_YS8Ug&usqp=CAU - as ./images\lavender\c87c08dd9d.jpg
# SUCCESS - saved https://i.ytimg.com/vi/ULafFi9YuG0/maxresdefault.jpg - as ./images\lavender\31ad1a6e0b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSz-aIfDP9_qtZmFlKiJgiXUKMKzyIpBQ9zew&usqp=CAU - as ./images\lavender\1193d83599.jpg
# ...

# %%
# creating a list of above
to_classify = ["cat","dog","frog","snake"]

for i in to_classify:
    search_term = i

    search_and_download(
        search_term = search_term,
        driver_path = DRIVER_PATH,
        number_images = 10
    )
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 11 image links, done!
# SUCCESS - saved https://static01.nyt.com/images/2021/09/14/science/07CAT-STRIPES/07CAT-STRIPES-mobileMasterAt3x.jpg - as ./images\cat\7c136232d3.jpg
# SUCCESS - saved https://cdn.britannica.com/39/7139-050-A88818BB/Himalayan-chocolate-point.jpg - as ./images\cat\898d8a470e.jpg
# SUCCESS - saved https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F47%2F2020%2F06%2F26%2Forange-kitten-955480082-2000.jpg - as ./images\cat\75755da7b1.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDUrDXsJS76TbzILgAirA-m0hAp6Np5Hvf-A&usqp=CAU - as ./images\cat\c7338a0a45.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4it_Jqeo2FMOA-0f2yJk5uYJ3YTa1j7MVSA&usqp=CAU - as ./images\cat\a3c770de55.jpg
# ...
