# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 40s 0us/step
# 228827136/228813984 [==============================] - 40s 0us/step

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x231 at 0x1DEC24D18E0>

# %%
#parameters for the loader
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9836597

# %%
num_classes = 5

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 70s 741ms/step - loss: 1.2651 - accuracy: 0.4615 - val_loss: 1.1169 - val_accuracy: 0.5531
# Epoch 2/10
# 92/92 [==============================] - 75s 817ms/step - loss: 1.0375 - accuracy: 0.6008 - val_loss: 0.9369 - val_accuracy: 0.6512
# Epoch 3/10
# 92/92 [==============================] - 63s 680ms/step - loss: 0.8407 - accuracy: 0.6710 - val_loss: 0.9471 - val_accuracy: 0.6335
# Epoch 4/10
# 92/92 [==============================] - 67s 728ms/step - loss: 0.6767 - accuracy: 0.7480 - val_loss: 0.8847 - val_accuracy: 0.6662
# Epoch 5/10
# 92/92 [==============================] - 65s 711ms/step - loss: 0.4556 - accuracy: 0.8399 - val_loss: 1.0396 - val_accuracy: 0.6580
# Epoch 6/10
# 92/92 [==============================] - 56s 613ms/step - loss: 0.2928 - accuracy: 0.8999 - val_loss: 1.1137 - val_accuracy: 0.6512
# Epoch 7/10
# 92/92 [==============================] - 50s 548ms/step - loss: 0.1840 - accuracy: 0.9384 - val_loss: 1.2679 - val_accuracy: 0.6458
# Epoch 8/10
# 92/92 [==============================] - 49s 537ms/step - loss: 0.1034 - accuracy: 0.9704 - val_loss: 1.4632 - val_accuracy: 0.6485
# Epoch 9/10
# 92/92 [==============================] - 65s 704ms/step - loss: 0.0763 - accuracy: 0.9785 - val_loss: 1.6253 - val_accuracy: 0.6444
# Epoch 10/10
# 92/92 [==============================] - 64s 697ms/step - loss: 0.0487 - accuracy: 0.9871 - val_loss: 1.7765 - val_accuracy: 0.6553

# %%
#visualizing results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#augmenting to prevent overfitting
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
#retraining
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 92/92 [==============================] - 83s 872ms/step - loss: 1.3411 - accuracy: 0.4319 - val_loss: 1.5791 - val_accuracy: 0.3842
# Epoch 2/15
# 92/92 [==============================] - 79s 860ms/step - loss: 1.0604 - accuracy: 0.5688 - val_loss: 1.0035 - val_accuracy: 0.6035
# Epoch 3/15
# 92/92 [==============================] - 78s 848ms/step - loss: 0.9836 - accuracy: 0.6155 - val_loss: 0.9448 - val_accuracy: 0.6185
# Epoch 4/15
# 92/92 [==============================] - 79s 855ms/step - loss: 0.8987 - accuracy: 0.6516 - val_loss: 0.8953 - val_accuracy: 0.6458
# Epoch 5/15
# 92/92 [==============================] - 79s 857ms/step - loss: 0.8470 - accuracy: 0.6809 - val_loss: 0.8701 - val_accuracy: 0.6689
# Epoch 6/15
# 92/92 [==============================] - 79s 863ms/step - loss: 0.8031 - accuracy: 0.6890 - val_loss: 0.8216 - val_accuracy: 0.6921
# Epoch 7/15
# 92/92 [==============================] - 81s 887ms/step - loss: 0.7761 - accuracy: 0.7047 - val_loss: 0.8524 - val_accuracy: 0.6662
# Epoch 8/15
# 92/92 [==============================] - 79s 860ms/step - loss: 0.7286 - accuracy: 0.7187 - val_loss: 0.8159 - val_accuracy: 0.6703
# Epoch 9/15
# 92/92 [==============================] - 78s 848ms/step - loss: 0.6979 - accuracy: 0.7347 - val_loss: 0.8072 - val_accuracy: 0.6771
# Epoch 10/15
# 92/92 [==============================] - 79s 855ms/step - loss: 0.6769 - accuracy: 0.7469 - val_loss: 0.7181 - val_accuracy: 0.7125
# Epoch 11/15
# 92/92 [==============================] - 79s 863ms/step - loss: 0.6567 - accuracy: 0.7439 - val_loss: 0.7844 - val_accuracy: 0.6962
# Epoch 12/15
# 92/92 [==============================] - 78s 850ms/step - loss: 0.6347 - accuracy: 0.7589 - val_loss: 0.7525 - val_accuracy: 0.6962
# Epoch 13/15
# 92/92 [==============================] - 78s 848ms/step - loss: 0.6170 - accuracy: 0.7541 - val_loss: 0.6946 - val_accuracy: 0.7316
# Epoch 14/15
# 92/92 [==============================] - 78s 845ms/step - loss: 0.5830 - accuracy: 0.7807 - val_loss: 0.7746 - val_accuracy: 0.7193
# Epoch 15/15
# 92/92 [==============================] - 72s 781ms/step - loss: 0.5665 - accuracy: 0.7871 - val_loss: 0.7449 - val_accuracy: 0.7084

# %%
#visualisation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
#sunflower_url = "https://www.google.com/search?q=tulip&sxsrf=AOaemvK3JXQvNaYAVHA54U0DzEQCW-4d8w:1631521870375&tbm=isch&source=iu&ictx=1&fir=hbmvVva8q2x2PM%252CiUuWNEtF2A2NNM%252C_&vet=1&usg=AI4_-kTCfniwhaDJwRm5wvb2sJJTqoNVhQ&sa=X&ved=2ahUKEwjOipvMxPvyAhXcxzgGHdcPDoUQ_h16BAggEAE#imgrc=hbmvVva8q2x2PM"
#sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)
img_test = "dog.jpg"
#img = keras.preprocessing.image.load_img(
 #   sunflower_path, target_size=(img_height, img_width)   
#)

img = keras.preprocessing.image.load_img(
    img_test, target_size=(img_height, img_width)   
)

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to roses with a 51.18 percent confidence.
